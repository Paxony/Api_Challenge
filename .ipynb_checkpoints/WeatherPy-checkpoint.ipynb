# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
temp_units = "Metric"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# Output File (CSV)
output_data_file = "Resources/weather_df.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_list = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_list.append(city)
        else:
            count_one += 1
            city_list.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
        print("--------------------------------------------------------")
    except Exception:
        print("City not found.... Searching...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | pisco
# --------------------------------------------------------
# Processing Record 2 of Set 1 | mar del plata
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 3 of Set 1 | flinders
# --------------------------------------------------------
# Processing Record 4 of Set 1 | albany
# --------------------------------------------------------
# Processing Record 5 of Set 1 | busselton
# --------------------------------------------------------
# Processing Record 6 of Set 1 | notre-dame-du-lac
# --------------------------------------------------------
# Processing Record 7 of Set 1 | san juan
# --------------------------------------------------------
# Processing Record 8 of Set 1 | kodiak
# --------------------------------------------------------
# Processing Record 9 of Set 1 | rikitea
# --------------------------------------------------------
# Processing Record 10 of Set 1 | kapaa
# --------------------------------------------------------
# Processing Record 11 of Set 1 | tasiilaq
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 12 of Set 1 | vestmannaeyjar
# --------------------------------------------------------
# Processing Record 13 of Set 1 | ribeira grande
# --------------------------------------------------------
# Processing Record 14 of Set 1 | punta arenas
# --------------------------------------------------------
# Processing Record 15 of Set 1 | bluff
# --------------------------------------------------------
# Processing Record 16 of Set 1 | talnakh
# --------------------------------------------------------
# Processing Record 17 of Set 1 | torbay
# --------------------------------------------------------
# Processing Record 18 of Set 1 | kavieng
# --------------------------------------------------------
# Processing Record 19 of Set 1 | castro
# --------------------------------------------------------
# Processing Record 20 of Set 1 | esperance
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 21 of Set 1 | sakaiminato
# --------------------------------------------------------
# Processing Record 22 of Set 1 | lagoa
# --------------------------------------------------------
# Processing Record 23 of Set 1 | hermanus
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 24 of Set 1 | praia
# --------------------------------------------------------
# Processing Record 25 of Set 1 | yuzhno-kurilsk
# --------------------------------------------------------
# Processing Record 26 of Set 1 | guerrero negro
# --------------------------------------------------------
# Processing Record 27 of Set 1 | pevek
# --------------------------------------------------------
# Processing Record 28 of Set 1 | east stroudsburg
# --------------------------------------------------------
# Processing Record 29 of Set 1 | mehamn
# --------------------------------------------------------
# Processing Record 30 of Set 1 | yellowknife
# --------------------------------------------------------
# Processing Record 31 of Set 1 | loukhi
# --------------------------------------------------------
# Processing Record 32 of Set 1 | honningsvag
# --------------------------------------------------------
# Processing Record 33 of Set 1 | tuktoyaktuk
# --------------------------------------------------------
# Processing Record 34 of Set 1 | jamestown
# --------------------------------------------------------
# Processing Record 35 of Set 1 | hilo
# --------------------------------------------------------
# Processing Record 36 of Set 1 | cururupu
# --------------------------------------------------------
# Processing Record 37 of Set 1 | lavrentiya
# --------------------------------------------------------
# Processing Record 38 of Set 1 | souillac
# --------------------------------------------------------
# Processing Record 39 of Set 1 | saint-philippe
# --------------------------------------------------------
# Processing Record 40 of Set 1 | luderitz
# --------------------------------------------------------
# Processing Record 41 of Set 1 | puerto ayora
# --------------------------------------------------------
# Processing Record 42 of Set 1 | zhezkazgan
# --------------------------------------------------------
# Processing Record 43 of Set 1 | mataura
# --------------------------------------------------------
# Processing Record 44 of Set 1 | namibe
# --------------------------------------------------------
# Processing Record 45 of Set 1 | pionerskiy
# --------------------------------------------------------
# Processing Record 46 of Set 1 | airai
# --------------------------------------------------------
# Processing Record 47 of Set 1 | rabkavi
# --------------------------------------------------------
# Processing Record 48 of Set 1 | fairbanks
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 1 | padang
# --------------------------------------------------------
# Processing Record 1 of Set 2 | bredasdorp
# --------------------------------------------------------
# Processing Record 2 of Set 2 | tilichiki
# --------------------------------------------------------
# Processing Record 3 of Set 2 | fukue
# --------------------------------------------------------
# Processing Record 4 of Set 2 | sao filipe
# --------------------------------------------------------
# Processing Record 5 of Set 2 | nanortalik
# --------------------------------------------------------
# Processing Record 6 of Set 2 | ushuaia
# --------------------------------------------------------
# Processing Record 7 of Set 2 | lompoc
# --------------------------------------------------------
# Processing Record 8 of Set 2 | tarakan
# --------------------------------------------------------
# Processing Record 9 of Set 2 | yerbogachen
# --------------------------------------------------------
# Processing Record 10 of Set 2 | new norfolk
# --------------------------------------------------------
# Processing Record 11 of Set 2 | deputatskiy
# --------------------------------------------------------
# Processing Record 12 of Set 2 | inirida
# --------------------------------------------------------
# Processing Record 13 of Set 2 | hithadhoo
# --------------------------------------------------------
# Processing Record 14 of Set 2 | nikolskoye
# --------------------------------------------------------
# Processing Record 15 of Set 2 | cairns
# --------------------------------------------------------
# Processing Record 16 of Set 2 | lebu
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 17 of Set 2 | port lincoln
# --------------------------------------------------------
# Processing Record 18 of Set 2 | faanui
# --------------------------------------------------------
# Processing Record 19 of Set 2 | sabile
# --------------------------------------------------------
# Processing Record 20 of Set 2 | bambous virieux
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 21 of Set 2 | arraial do cabo
# --------------------------------------------------------
# Processing Record 22 of Set 2 | north bend
# --------------------------------------------------------
# Processing Record 23 of Set 2 | bethel
# --------------------------------------------------------
# Processing Record 24 of Set 2 | krasnyy kurgan
# --------------------------------------------------------
# Processing Record 25 of Set 2 | severo-kurilsk
# --------------------------------------------------------
# Processing Record 26 of Set 2 | tura
# --------------------------------------------------------
# Processing Record 27 of Set 2 | catuday
# --------------------------------------------------------
# Processing Record 28 of Set 2 | palmer
# --------------------------------------------------------
# Processing Record 29 of Set 2 | isangel
# --------------------------------------------------------
# Processing Record 30 of Set 2 | clyde river
# --------------------------------------------------------
# Processing Record 31 of Set 2 | vanavara
# --------------------------------------------------------
# Processing Record 32 of Set 2 | avarua
# --------------------------------------------------------
# Processing Record 33 of Set 2 | yongan
# --------------------------------------------------------
# Processing Record 34 of Set 2 | thompson
# --------------------------------------------------------
# Processing Record 35 of Set 2 | neuquen
# --------------------------------------------------------
# Processing Record 36 of Set 2 | valdivia
# --------------------------------------------------------
# Processing Record 37 of Set 2 | grand river south east
# --------------------------------------------------------
# Processing Record 38 of Set 2 | bocanda
# --------------------------------------------------------
# Processing Record 39 of Set 2 | saldanha
# --------------------------------------------------------
# Processing Record 40 of Set 2 | okha
# --------------------------------------------------------
# Processing Record 41 of Set 2 | bronte
# --------------------------------------------------------
# Processing Record 42 of Set 2 | port elizabeth
# --------------------------------------------------------
# Processing Record 43 of Set 2 | scarborough
# --------------------------------------------------------
# Processing Record 44 of Set 2 | hoopstad
# --------------------------------------------------------
# Processing Record 45 of Set 2 | sanary-sur-mer
# --------------------------------------------------------
# Processing Record 46 of Set 2 | dikson
# --------------------------------------------------------
# Processing Record 47 of Set 2 | chokurdakh
# --------------------------------------------------------
# Processing Record 48 of Set 2 | micheweni
# --------------------------------------------------------
# Processing Record 49 of Set 2 | avera
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 1 of Set 3 | katsuura
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 2 of Set 3 | innerleithen
# --------------------------------------------------------
# Processing Record 3 of Set 3 | trincomalee
# --------------------------------------------------------
# Processing Record 4 of Set 3 | kaitangata
# --------------------------------------------------------
# Processing Record 5 of Set 3 | narsaq
# --------------------------------------------------------
# Processing Record 6 of Set 3 | east london
# --------------------------------------------------------
# Processing Record 7 of Set 3 | ebeltoft
# --------------------------------------------------------
# Processing Record 8 of Set 3 | qaanaaq
# --------------------------------------------------------
# Processing Record 9 of Set 3 | college
# --------------------------------------------------------
# Processing Record 10 of Set 3 | ancud
# --------------------------------------------------------
# Processing Record 11 of Set 3 | geraldton
# --------------------------------------------------------
# Processing Record 12 of Set 3 | longyearbyen
# --------------------------------------------------------
# Processing Record 13 of Set 3 | sens
# --------------------------------------------------------
# Processing Record 14 of Set 3 | smithers
# --------------------------------------------------------
# Processing Record 15 of Set 3 | port hedland
# --------------------------------------------------------
# Processing Record 16 of Set 3 | barraute
# --------------------------------------------------------
# Processing Record 17 of Set 3 | norman wells
# --------------------------------------------------------
# Processing Record 18 of Set 3 | kachug
# --------------------------------------------------------
# Processing Record 19 of Set 3 | san rafael
# --------------------------------------------------------
# Processing Record 20 of Set 3 | san patricio
# --------------------------------------------------------
# Processing Record 21 of Set 3 | hobart
# --------------------------------------------------------
# Processing Record 22 of Set 3 | atuona
# --------------------------------------------------------
# Processing Record 23 of Set 3 | wenling
# --------------------------------------------------------
# Processing Record 24 of Set 3 | haimen
# --------------------------------------------------------
# Processing Record 25 of Set 3 | colgong
# --------------------------------------------------------
# Processing Record 26 of Set 3 | gidam
# --------------------------------------------------------
# Processing Record 27 of Set 3 | cherskiy
# --------------------------------------------------------
# Processing Record 28 of Set 3 | bathsheba
# --------------------------------------------------------
# Processing Record 29 of Set 3 | komsomolskiy
# --------------------------------------------------------
# Processing Record 30 of Set 3 | chapais
# --------------------------------------------------------
# Processing Record 31 of Set 3 | havelock
# --------------------------------------------------------
# Processing Record 32 of Set 3 | povenets
# --------------------------------------------------------
# Processing Record 33 of Set 3 | cockburn harbour
# --------------------------------------------------------
# Processing Record 34 of Set 3 | luoyang
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 35 of Set 3 | shimoda
# --------------------------------------------------------
# Processing Record 36 of Set 3 | gorey
# --------------------------------------------------------
# Processing Record 37 of Set 3 | grand-santi
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 38 of Set 3 | dingle
# --------------------------------------------------------
# Processing Record 39 of Set 3 | ambilobe
# --------------------------------------------------------
# Processing Record 40 of Set 3 | odienne
# --------------------------------------------------------
# Processing Record 41 of Set 3 | samarkand
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 42 of Set 3 | iqaluit
# --------------------------------------------------------
# Processing Record 43 of Set 3 | kruisfontein
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 44 of Set 3 | denpasar
# --------------------------------------------------------
# Processing Record 45 of Set 3 | itarema
# --------------------------------------------------------
# Processing Record 46 of Set 3 | severo-yeniseyskiy
# --------------------------------------------------------
# Processing Record 47 of Set 3 | moree
# --------------------------------------------------------
# Processing Record 48 of Set 3 | codrington
# --------------------------------------------------------
# Processing Record 49 of Set 3 | tingi
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 1 of Set 4 | hovd
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 2 of Set 4 | ahipara
# --------------------------------------------------------
# Processing Record 3 of Set 4 | kirakira
# --------------------------------------------------------
# Processing Record 4 of Set 4 | izberbash
# --------------------------------------------------------
# Processing Record 5 of Set 4 | kiunga
# --------------------------------------------------------
# Processing Record 6 of Set 4 | canon city
# --------------------------------------------------------
# Processing Record 7 of Set 4 | samarai
# --------------------------------------------------------
# Processing Record 8 of Set 4 | skjervoy
# --------------------------------------------------------
# Processing Record 9 of Set 4 | half moon bay
# --------------------------------------------------------
# Processing Record 10 of Set 4 | strezhevoy
# --------------------------------------------------------
# Processing Record 11 of Set 4 | guilin
# --------------------------------------------------------
# Processing Record 12 of Set 4 | chuy
# --------------------------------------------------------
# Processing Record 13 of Set 4 | buchanan
# --------------------------------------------------------
# Processing Record 14 of Set 4 | vostok
# --------------------------------------------------------
# Processing Record 15 of Set 4 | ilulissat
# --------------------------------------------------------
# Processing Record 16 of Set 4 | touros
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 17 of Set 4 | olinda
# --------------------------------------------------------
# Processing Record 18 of Set 4 | chitungwiza
# --------------------------------------------------------
# Processing Record 19 of Set 4 | urman
# --------------------------------------------------------
# Processing Record 20 of Set 4 | grindavik
# --------------------------------------------------------
# Processing Record 21 of Set 4 | adrar
# --------------------------------------------------------
# Processing Record 22 of Set 4 | kakonko
# --------------------------------------------------------
# Processing Record 23 of Set 4 | prieska
# --------------------------------------------------------
# Processing Record 24 of Set 4 | khandyga
# --------------------------------------------------------
# Processing Record 25 of Set 4 | comodoro rivadavia
# --------------------------------------------------------
# Processing Record 26 of Set 4 | gejiu
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 27 of Set 4 | mys shmidta
# --------------------------------------------------------
# Processing Record 28 of Set 4 | poum
# --------------------------------------------------------
# Processing Record 29 of Set 4 | tagusao
# --------------------------------------------------------
# Processing Record 30 of Set 4 | meulaboh
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 31 of Set 4 | hasaki
# --------------------------------------------------------
# Processing Record 32 of Set 4 | husavik
# --------------------------------------------------------
# Processing Record 33 of Set 4 | gat
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 34 of Set 4 | plettenberg bay
# --------------------------------------------------------
# Processing Record 35 of Set 4 | virginia beach
# --------------------------------------------------------
# Processing Record 36 of Set 4 | axim
# --------------------------------------------------------
# Processing Record 37 of Set 4 | coari
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 38 of Set 4 | tocopilla
# --------------------------------------------------------
# Processing Record 39 of Set 4 | tezu
# --------------------------------------------------------
# Processing Record 40 of Set 4 | pangai
# --------------------------------------------------------
# Processing Record 41 of Set 4 | rocha
# --------------------------------------------------------
# Processing Record 42 of Set 4 | cabo san lucas
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 43 of Set 4 | talara
# --------------------------------------------------------
# Processing Record 44 of Set 4 | ketchikan
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 45 of Set 4 | orbetello
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 46 of Set 4 | ahar
# --------------------------------------------------------
# Processing Record 47 of Set 4 | coolidge
# --------------------------------------------------------
# Processing Record 48 of Set 4 | richards bay
# --------------------------------------------------------
# Processing Record 49 of Set 4 | kenmare
# --------------------------------------------------------
# Processing Record 1 of Set 5 | rawson
# --------------------------------------------------------
# Processing Record 2 of Set 5 | alofi
# --------------------------------------------------------
# Processing Record 3 of Set 5 | pipri
# --------------------------------------------------------
# Processing Record 4 of Set 5 | cape town
# --------------------------------------------------------
# Processing Record 5 of Set 5 | japura
# --------------------------------------------------------
# Processing Record 6 of Set 5 | labuhan
# --------------------------------------------------------
# Processing Record 7 of Set 5 | khatanga
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 8 of Set 5 | karratha
# --------------------------------------------------------
# Processing Record 9 of Set 5 | urucara
# --------------------------------------------------------
# Processing Record 10 of Set 5 | coihaique
# --------------------------------------------------------
# Processing Record 11 of Set 5 | palestine
# --------------------------------------------------------
# Processing Record 12 of Set 5 | kadaya
# --------------------------------------------------------
# Processing Record 13 of Set 5 | caravelas
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 14 of Set 5 | springbok
# --------------------------------------------------------
# Processing Record 15 of Set 5 | carnarvon
# --------------------------------------------------------
# Processing Record 16 of Set 5 | kawambwa
# --------------------------------------------------------
# Processing Record 17 of Set 5 | hobyo
# --------------------------------------------------------
# Processing Record 18 of Set 5 | zapolyarnyy
# --------------------------------------------------------
# Processing Record 19 of Set 5 | najran
# --------------------------------------------------------
# Processing Record 20 of Set 5 | pamekasan
# --------------------------------------------------------
# Processing Record 21 of Set 5 | bria
# --------------------------------------------------------
# Processing Record 22 of Set 5 | teknaf
# --------------------------------------------------------
# Processing Record 23 of Set 5 | intipuca
# --------------------------------------------------------
# Processing Record 24 of Set 5 | porbandar
# --------------------------------------------------------
# Processing Record 25 of Set 5 | srednekolymsk
# --------------------------------------------------------
# Processing Record 26 of Set 5 | puerto pailas
# --------------------------------------------------------
# Processing Record 27 of Set 5 | yar-sale
# --------------------------------------------------------
# Processing Record 28 of Set 5 | berezovka
# --------------------------------------------------------
# Processing Record 29 of Set 5 | payo
# --------------------------------------------------------
# Processing Record 30 of Set 5 | douentza
# --------------------------------------------------------
# Processing Record 31 of Set 5 | klaksvik
# --------------------------------------------------------
# Processing Record 32 of Set 5 | georgetown
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 33 of Set 5 | butaritari
# --------------------------------------------------------
# Processing Record 34 of Set 5 | mount gambier
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 35 of Set 5 | leshukonskoye
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 36 of Set 5 | cidreira
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 37 of Set 5 | vaini
# --------------------------------------------------------
# Processing Record 38 of Set 5 | cortes
# --------------------------------------------------------
# Processing Record 39 of Set 5 | dali
# --------------------------------------------------------
# Processing Record 40 of Set 5 | ust-kulom
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 41 of Set 5 | peleduy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 42 of Set 5 | port alfred
# --------------------------------------------------------
# Processing Record 43 of Set 5 | saskylakh
# --------------------------------------------------------
# Processing Record 44 of Set 5 | altamont
# --------------------------------------------------------
# Processing Record 45 of Set 5 | birjand
# --------------------------------------------------------
# Processing Record 46 of Set 5 | whitianga
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 47 of Set 5 | barrow
# --------------------------------------------------------
# Processing Record 48 of Set 5 | porirua
# --------------------------------------------------------
# Processing Record 49 of Set 5 | aktau
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 1 of Set 6 | manta
# --------------------------------------------------------
# Processing Record 2 of Set 6 | tshikapa
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 3 of Set 6 | hecun
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 4 of Set 6 | saint-georges
# --------------------------------------------------------
# Processing Record 5 of Set 6 | valparaiso
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 6 of Set 6 | jais
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 7 of Set 6 | fortuna
# --------------------------------------------------------
# Processing Record 8 of Set 6 | cockburn town
# --------------------------------------------------------
# Processing Record 9 of Set 6 | hammerfest
# --------------------------------------------------------
# Processing Record 10 of Set 6 | leningradskiy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 11 of Set 6 | victoria
# --------------------------------------------------------
# Processing Record 12 of Set 6 | makubetsu
# --------------------------------------------------------
# Processing Record 13 of Set 6 | kavali
# --------------------------------------------------------
# Processing Record 14 of Set 6 | upernavik
# --------------------------------------------------------
# Processing Record 15 of Set 6 | margate
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 16 of Set 6 | brae
# --------------------------------------------------------
# Processing Record 17 of Set 6 | warrington
# --------------------------------------------------------
# Processing Record 18 of Set 6 | constitucion
# --------------------------------------------------------
# Processing Record 19 of Set 6 | belyy yar
# --------------------------------------------------------
# Processing Record 20 of Set 6 | tondi
# --------------------------------------------------------
# Processing Record 21 of Set 6 | gola bazar
# --------------------------------------------------------
# Processing Record 22 of Set 6 | alyangula
# --------------------------------------------------------
# Processing Record 23 of Set 6 | kuryk
# --------------------------------------------------------
# Processing Record 24 of Set 6 | haines junction
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 25 of Set 6 | waipawa
# --------------------------------------------------------
# Processing Record 26 of Set 6 | sitka
# --------------------------------------------------------
# Processing Record 27 of Set 6 | zarubino
# --------------------------------------------------------
# Processing Record 28 of Set 6 | moroni
# --------------------------------------------------------
# Processing Record 29 of Set 6 | kalga
# --------------------------------------------------------
# Processing Record 30 of Set 6 | whitehorse
# --------------------------------------------------------
# Processing Record 31 of Set 6 | hervey bay
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 32 of Set 6 | debno
# --------------------------------------------------------
# Processing Record 33 of Set 6 | winton
# --------------------------------------------------------
# Processing Record 34 of Set 6 | praia da vitoria
# --------------------------------------------------------
# Processing Record 35 of Set 6 | teya
# --------------------------------------------------------
# Processing Record 36 of Set 6 | lorengau
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 37 of Set 6 | vao
# --------------------------------------------------------
# Processing Record 38 of Set 6 | burnie
# --------------------------------------------------------
# Processing Record 39 of Set 6 | vestmanna
# --------------------------------------------------------
# Processing Record 40 of Set 6 | lata
# --------------------------------------------------------
# Processing Record 41 of Set 6 | porto novo
# --------------------------------------------------------
# Processing Record 42 of Set 6 | sibolga
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 43 of Set 6 | san cristobal
# --------------------------------------------------------
# Processing Record 44 of Set 6 | along
# --------------------------------------------------------
# Processing Record 45 of Set 6 | takoradi
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 46 of Set 6 | tiksi
# --------------------------------------------------------
# Processing Record 47 of Set 6 | cleveland
# --------------------------------------------------------
# Processing Record 48 of Set 6 | porto belo
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 6 | lykhivka
# --------------------------------------------------------
# Processing Record 1 of Set 7 | tautira
# --------------------------------------------------------
# Processing Record 2 of Set 7 | igrim
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 3 of Set 7 | sikonge
# --------------------------------------------------------
# Processing Record 4 of Set 7 | san javier
# --------------------------------------------------------
# Processing Record 5 of Set 7 | igarka
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 6 of Set 7 | bandarbeyla
# --------------------------------------------------------
# Processing Record 7 of Set 7 | bonavista
# --------------------------------------------------------
# Processing Record 8 of Set 7 | orange cove
# --------------------------------------------------------
# Processing Record 9 of Set 7 | manaure
# --------------------------------------------------------
# Processing Record 10 of Set 7 | sarangani
# --------------------------------------------------------
# Processing Record 11 of Set 7 | kutum
# --------------------------------------------------------
# Processing Record 12 of Set 7 | saint-francois
# --------------------------------------------------------
# Processing Record 13 of Set 7 | novoshcherbinovskaya
# --------------------------------------------------------
# Processing Record 14 of Set 7 | karpathos
# --------------------------------------------------------
# Processing Record 15 of Set 7 | lucapa
# --------------------------------------------------------
# Processing Record 16 of Set 7 | saint-pierre
# --------------------------------------------------------
# Processing Record 17 of Set 7 | ulladulla
# --------------------------------------------------------
# Processing Record 18 of Set 7 | tsiroanomandidy
# --------------------------------------------------------
# Processing Record 19 of Set 7 | terra nova
# --------------------------------------------------------
# Processing Record 20 of Set 7 | emerald
# --------------------------------------------------------
# Processing Record 21 of Set 7 | curup
# --------------------------------------------------------
# Processing Record 22 of Set 7 | anadyr
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 23 of Set 7 | siocon
# --------------------------------------------------------
# Processing Record 24 of Set 7 | ustye
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 25 of Set 7 | vila franca do campo
# --------------------------------------------------------
# Processing Record 26 of Set 7 | cayenne
# --------------------------------------------------------
# Processing Record 27 of Set 7 | castro-urdiales
# --------------------------------------------------------
# Processing Record 28 of Set 7 | mount isa
# --------------------------------------------------------
# Processing Record 29 of Set 7 | datong
# --------------------------------------------------------
# Processing Record 30 of Set 7 | vasai
# --------------------------------------------------------
# Processing Record 31 of Set 7 | port-gentil
# --------------------------------------------------------
# Processing Record 32 of Set 7 | doha
# --------------------------------------------------------
# Processing Record 33 of Set 7 | kualakapuas
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 34 of Set 7 | mahebourg
# --------------------------------------------------------
# Processing Record 35 of Set 7 | arlit
# --------------------------------------------------------
# Processing Record 36 of Set 7 | mocuba
# --------------------------------------------------------
# Processing Record 37 of Set 7 | aksu
# --------------------------------------------------------
# Processing Record 38 of Set 7 | maxixe
# --------------------------------------------------------
# Processing Record 39 of Set 7 | manokwari
# --------------------------------------------------------
# Processing Record 40 of Set 7 | diamantino
# --------------------------------------------------------
# Processing Record 41 of Set 7 | taiobeiras
# --------------------------------------------------------
# Processing Record 42 of Set 7 | kidal
# --------------------------------------------------------
# Processing Record 43 of Set 7 | parana
# --------------------------------------------------------
# Processing Record 44 of Set 7 | vila velha
# --------------------------------------------------------
# Processing Record 45 of Set 7 | findochty
# --------------------------------------------------------
# Processing Record 46 of Set 7 | kolvereid
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 47 of Set 7 | kysyl-syr
# --------------------------------------------------------
# Processing Record 48 of Set 7 | vredendal
# --------------------------------------------------------
# Processing Record 49 of Set 7 | babra
# --------------------------------------------------------
# Processing Record 1 of Set 8 | ponta do sol
# --------------------------------------------------------
# Processing Record 2 of Set 8 | pangnirtung
# --------------------------------------------------------
# Processing Record 3 of Set 8 | jardim
# --------------------------------------------------------
# Processing Record 4 of Set 8 | sao joao da barra
# --------------------------------------------------------
# Processing Record 5 of Set 8 | fakel
# --------------------------------------------------------
# Processing Record 6 of Set 8 | laguna
# --------------------------------------------------------
# Processing Record 7 of Set 8 | halifax
# --------------------------------------------------------
# Processing Record 8 of Set 8 | bilibino
# --------------------------------------------------------
# Processing Record 9 of Set 8 | sabang
# --------------------------------------------------------
# Processing Record 10 of Set 8 | vertou
# --------------------------------------------------------
# Processing Record 11 of Set 8 | ajdabiya
# --------------------------------------------------------
# Processing Record 12 of Set 8 | sun valley
# --------------------------------------------------------
# Processing Record 13 of Set 8 | nehe
# --------------------------------------------------------
# Processing Record 14 of Set 8 | nelson bay
# --------------------------------------------------------
# Processing Record 15 of Set 8 | falun
# --------------------------------------------------------
# Processing Record 16 of Set 8 | valence
# --------------------------------------------------------
# Processing Record 17 of Set 8 | monchegorsk
# --------------------------------------------------------
# Processing Record 18 of Set 8 | del rio
# --------------------------------------------------------
# Processing Record 19 of Set 8 | brownsville
# --------------------------------------------------------
# Processing Record 20 of Set 8 | tambun
# --------------------------------------------------------
# Processing Record 21 of Set 8 | mattru
# --------------------------------------------------------
# Processing Record 22 of Set 8 | constanza
# --------------------------------------------------------
# Processing Record 23 of Set 8 | north myrtle beach
# --------------------------------------------------------
# Processing Record 24 of Set 8 | redlands
# --------------------------------------------------------
# Processing Record 25 of Set 8 | vardo
# --------------------------------------------------------
# Processing Record 26 of Set 8 | rancho palos verdes
# --------------------------------------------------------
# Processing Record 27 of Set 8 | mpongwe
# --------------------------------------------------------
# Processing Record 28 of Set 8 | genhe
# --------------------------------------------------------
# Processing Record 29 of Set 8 | escarcega
# --------------------------------------------------------
# Processing Record 30 of Set 8 | muzhi
# --------------------------------------------------------
# Processing Record 31 of Set 8 | san ignacio
# --------------------------------------------------------
# Processing Record 32 of Set 8 | fernie
# --------------------------------------------------------
# Processing Record 33 of Set 8 | ostrovnoy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 34 of Set 8 | carbonia
# --------------------------------------------------------
# Processing Record 35 of Set 8 | kletnya
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 36 of Set 8 | douglas
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 37 of Set 8 | dicabisagan
# --------------------------------------------------------
# Processing Record 38 of Set 8 | sisimiut
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 39 of Set 8 | necochea
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 40 of Set 8 | tomatlan
# --------------------------------------------------------
# Processing Record 41 of Set 8 | nemuro
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 42 of Set 8 | lazaro cardenas
# --------------------------------------------------------
# Processing Record 43 of Set 8 | sambava
# --------------------------------------------------------
# Processing Record 44 of Set 8 | rawlins
# --------------------------------------------------------
# Processing Record 45 of Set 8 | camocim
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 46 of Set 8 | andijon
# --------------------------------------------------------
# Processing Record 47 of Set 8 | wetaskiwin
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 48 of Set 8 | havoysund
# --------------------------------------------------------
# Processing Record 49 of Set 8 | rafai
# --------------------------------------------------------
# Processing Record 1 of Set 9 | madison heights
# --------------------------------------------------------
# Processing Record 2 of Set 9 | sangar
# --------------------------------------------------------
# Processing Record 3 of Set 9 | langham
# --------------------------------------------------------
# Processing Record 4 of Set 9 | nguruka
# --------------------------------------------------------
# Processing Record 5 of Set 9 | tombouctou
# --------------------------------------------------------
# Processing Record 6 of Set 9 | yatou
# --------------------------------------------------------
# Processing Record 7 of Set 9 | basco
# --------------------------------------------------------
# Processing Record 8 of Set 9 | yarada
# --------------------------------------------------------
# Processing Record 9 of Set 9 | hornepayne
# --------------------------------------------------------
# Processing Record 10 of Set 9 | vero beach
# --------------------------------------------------------
# Processing Record 11 of Set 9 | omboue
# --------------------------------------------------------
# Processing Record 12 of Set 9 | kaabong
# --------------------------------------------------------
# Processing Record 13 of Set 9 | sao felix do xingu
# --------------------------------------------------------
# Processing Record 14 of Set 9 | norrtalje
# --------------------------------------------------------
# Processing Record 15 of Set 9 | dunedin
# --------------------------------------------------------
# Processing Record 16 of Set 9 | morehead
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 17 of Set 9 | buala
# --------------------------------------------------------
# Processing Record 18 of Set 9 | ojinaga
# --------------------------------------------------------
# Processing Record 19 of Set 9 | okhotsk
# --------------------------------------------------------
# Processing Record 20 of Set 9 | salta
# --------------------------------------------------------
# Processing Record 21 of Set 9 | tuatapere
# --------------------------------------------------------
# Processing Record 22 of Set 9 | ushirombo
# --------------------------------------------------------
# Processing Record 23 of Set 9 | vangaindrano
# --------------------------------------------------------
# Processing Record 24 of Set 9 | coquimbo
# --------------------------------------------------------
# Processing Record 25 of Set 9 | xining
# --------------------------------------------------------
# Processing Record 26 of Set 9 | camacha
# --------------------------------------------------------
# Processing Record 27 of Set 9 | banda aceh
# --------------------------------------------------------
# Processing Record 28 of Set 9 | chongwe
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 29 of Set 9 | veendam
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 30 of Set 9 | mohnesee
# --------------------------------------------------------
# Processing Record 31 of Set 9 | darnah
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 32 of Set 9 | faya
# --------------------------------------------------------
# Processing Record 33 of Set 9 | jinka
# --------------------------------------------------------
# Processing Record 34 of Set 9 | ozark
# --------------------------------------------------------
# Processing Record 35 of Set 9 | synya
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 36 of Set 9 | rome
# --------------------------------------------------------
# Processing Record 37 of Set 9 | fare
# --------------------------------------------------------
# Processing Record 38 of Set 9 | chimbote
# --------------------------------------------------------
# Processing Record 39 of Set 9 | prince rupert
# --------------------------------------------------------
# Processing Record 40 of Set 9 | damara
# --------------------------------------------------------
# Processing Record 41 of Set 9 | salalah
# --------------------------------------------------------
# Processing Record 42 of Set 9 | buzmeyin
# --------------------------------------------------------
# Processing Record 43 of Set 9 | hofn
# --------------------------------------------------------
# Processing Record 44 of Set 9 | moncton
# --------------------------------------------------------
# Processing Record 45 of Set 9 | brokopondo
# --------------------------------------------------------
# Processing Record 46 of Set 9 | manggar
# --------------------------------------------------------
# Processing Record 47 of Set 9 | chernyshevskiy
# --------------------------------------------------------
# Processing Record 48 of Set 9 | kawalu
# --------------------------------------------------------
# Processing Record 49 of Set 9 | buin
# --------------------------------------------------------
# Processing Record 1 of Set 10 | chara
# --------------------------------------------------------
# Processing Record 2 of Set 10 | jiazi
# --------------------------------------------------------
# Processing Record 3 of Set 10 | yulara
# --------------------------------------------------------
# Processing Record 4 of Set 10 | beloha
# --------------------------------------------------------
# Processing Record 5 of Set 10 | loanda
# --------------------------------------------------------
# Processing Record 6 of Set 10 | baykit
# --------------------------------------------------------
# Processing Record 7 of Set 10 | braesti
# --------------------------------------------------------
# Processing Record 8 of Set 10 | tadine
# --------------------------------------------------------
# Processing Record 9 of Set 10 | caernarfon
# --------------------------------------------------------
# Processing Record 10 of Set 10 | nyimba
# --------------------------------------------------------
# Processing Record 11 of Set 10 | mayo
# --------------------------------------------------------
# Processing Record 12 of Set 10 | voyvozh
# --------------------------------------------------------
# Processing Record 13 of Set 10 | luanda
# --------------------------------------------------------
# Processing Record 14 of Set 10 | rio gallegos
# --------------------------------------------------------
# Processing Record 15 of Set 10 | kattivakkam
# --------------------------------------------------------
# Processing Record 16 of Set 10 | lasa
# --------------------------------------------------------
# Processing Record 17 of Set 10 | port hardy
# --------------------------------------------------------
# Processing Record 18 of Set 10 | bud
# --------------------------------------------------------
# Processing Record 19 of Set 10 | kapit
# --------------------------------------------------------
# Processing Record 20 of Set 10 | guaruja
# --------------------------------------------------------
# Processing Record 21 of Set 10 | atar
# --------------------------------------------------------
# Processing Record 22 of Set 10 | beaverlodge
# --------------------------------------------------------
# Processing Record 23 of Set 10 | grand gaube
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 24 of Set 10 | aswan
# --------------------------------------------------------
# Processing Record 25 of Set 10 | taoudenni
# --------------------------------------------------------
# Processing Record 26 of Set 10 | juneau
# --------------------------------------------------------
# Processing Record 27 of Set 10 | khuzhir
# --------------------------------------------------------
# Processing Record 28 of Set 10 | kavaratti
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 29 of Set 10 | turayf
# --------------------------------------------------------
# Processing Record 30 of Set 10 | broome
# --------------------------------------------------------
# Processing Record 31 of Set 10 | provideniya
# --------------------------------------------------------
# Processing Record 32 of Set 10 | trinidad
# --------------------------------------------------------
# Processing Record 33 of Set 10 | pangkalanbuun
# --------------------------------------------------------
# Processing Record 34 of Set 10 | sur
# --------------------------------------------------------
# Processing Record 35 of Set 10 | athabasca
# --------------------------------------------------------
# Processing Record 36 of Set 10 | nizwa
# --------------------------------------------------------
# Processing Record 37 of Set 10 | inuvik
# --------------------------------------------------------
# Processing Record 38 of Set 10 | nanakuli
# --------------------------------------------------------
# Processing Record 39 of Set 10 | chama
# --------------------------------------------------------
# Processing Record 40 of Set 10 | idrinskoye
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 41 of Set 10 | taltal
# --------------------------------------------------------
# Processing Record 42 of Set 10 | uaua
# --------------------------------------------------------
# Processing Record 43 of Set 10 | keller
# --------------------------------------------------------
# Processing Record 44 of Set 10 | goderich
# --------------------------------------------------------
# Processing Record 45 of Set 10 | evensk
# --------------------------------------------------------
# Processing Record 46 of Set 10 | verkhoyansk
# --------------------------------------------------------
# Processing Record 47 of Set 10 | esmeraldas
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 48 of Set 10 | fort nelson
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 10 | port blair
# --------------------------------------------------------
# Processing Record 1 of Set 11 | aviles
# --------------------------------------------------------
# Processing Record 2 of Set 11 | leogane
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 3 of Set 11 | jalu
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 4 of Set 11 | westport
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 5 of Set 11 | peterhead
# --------------------------------------------------------
# Processing Record 6 of Set 11 | andreapol
# --------------------------------------------------------
# Processing Record 7 of Set 11 | pavino
# --------------------------------------------------------
# Processing Record 8 of Set 11 | itoman
# --------------------------------------------------------
# Processing Record 9 of Set 11 | liverpool
# --------------------------------------------------------
# Processing Record 10 of Set 11 | porto santo
# --------------------------------------------------------
# Processing Record 11 of Set 11 | locri
# --------------------------------------------------------
# Processing Record 12 of Set 11 | arman
# --------------------------------------------------------
# Processing Record 13 of Set 11 | nenjiang
# --------------------------------------------------------
# Processing Record 14 of Set 11 | aklavik
# --------------------------------------------------------
# Processing Record 15 of Set 11 | kantabanji
# --------------------------------------------------------
# Processing Record 16 of Set 11 | nome
# --------------------------------------------------------
# Processing Record 17 of Set 11 | novoanninskiy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 18 of Set 11 | raudeberg
# --------------------------------------------------------
# Processing Record 19 of Set 11 | honiara
# --------------------------------------------------------
# Processing Record 20 of Set 11 | mecca
# --------------------------------------------------------
# Processing Record 21 of Set 11 | charters towers
# --------------------------------------------------------
# Processing Record 22 of Set 11 | vanimo
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_list,
    "Country":countries,
    "Cloudiness":cloudinesses,
    "Humidity":humidities,
    "Latitude":lats,
    "Longitude":lngs,
    "Max Temperature":max_temps,
    "Wind Speed":wind_speeds
}

# %%
# establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)

# %%
# show the top of the dataframe
weather_dataframe.head()
# Out:
#             City Country  Cloudiness  Humidity  Latitude  Longitude  \
# 0          pisco      PE          40        30    -13.71     -76.20
# 1  mar del plata      CN           0        77     29.86      90.73
# 2       flinders      AU          40        71    -34.58     150.85
# 3         albany      US          75        59     42.65     -73.75
# 4      busselton      AU         100        61    -33.64     115.35
#
#    Max Temperature  Wind Speed
# 0            22.00       5.100
# 1            -0.40       1.949
# 2            15.56       6.700
# 3            17.00       3.100
# 4            13.33       7.420

# %%
# output data to csv
weather_dataframe.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Generate the Plot lat vs. Temp

plt.scatter(weather_dataframe["Latitude"],weather_dataframe["Max Temperature"] )


plt.ylim(-25,60)

# Chart title
plt.title("City Latitude VS Max Temperature")
# x label
plt.xlabel("Temperature")
# y label
plt.ylabel("Max Temperature (°C)")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Generate the Plot lat vs. Humidity

plt.scatter(weather_dataframe["Latitude"],weather_dataframe["Humidity"] )


plt.ylim(-5,115)

# Chart title
plt.title("City Latitude VS Humidity")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Humidity")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSHum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Generate the Plot lat vs. Cloudiness

plt.scatter(weather_dataframe["Latitude"],weather_dataframe["Cloudiness"] )


plt.ylim(-15,125)

# Chart title
plt.title("City Latitude VS Cloudiness")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Cloudiness")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSCloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Generate the Plot lat vs. Wind Speed

plt.scatter(weather_dataframe["Latitude"],weather_dataframe["Wind Speed"] )


# Chart title
plt.title("City Latitude VS Wind Speed")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Wind Speed (meter/sec)")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSWind.png")
