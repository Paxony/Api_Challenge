# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#it's true the weather near to ecuator is hotter
#The north have more humidity in this season (october 2019)
#There's no clear relation whith cloudiness to the ecuator

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
temp_units = "Imperial"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# Output File (CSV)
output_data_file = "Resources/weather_df.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_list = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_list.append(city)
        else:
            count_one += 1
            city_list.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
        print("--------------------------------------------------------")
    except Exception:
        print("City not found.... Searching...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | qaanaaq
# --------------------------------------------------------
# Processing Record 2 of Set 1 | rikitea
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 3 of Set 1 | corinto
# --------------------------------------------------------
# Processing Record 4 of Set 1 | atuona
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 5 of Set 1 | port alfred
# --------------------------------------------------------
# Processing Record 6 of Set 1 | constitucion
# --------------------------------------------------------
# Processing Record 7 of Set 1 | albany
# --------------------------------------------------------
# Processing Record 8 of Set 1 | hermanus
# --------------------------------------------------------
# Processing Record 9 of Set 1 | upington
# --------------------------------------------------------
# Processing Record 10 of Set 1 | hithadhoo
# --------------------------------------------------------
# Processing Record 11 of Set 1 | saskylakh
# --------------------------------------------------------
# Processing Record 12 of Set 1 | balkanabat
# --------------------------------------------------------
# Processing Record 13 of Set 1 | natitingou
# --------------------------------------------------------
# Processing Record 14 of Set 1 | ushuaia
# --------------------------------------------------------
# Processing Record 15 of Set 1 | touros
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 16 of Set 1 | pangody
# --------------------------------------------------------
# Processing Record 17 of Set 1 | mataura
# --------------------------------------------------------
# Processing Record 18 of Set 1 | tuktoyaktuk
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 19 of Set 1 | ixtapa
# --------------------------------------------------------
# Processing Record 20 of Set 1 | pundaguitan
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 21 of Set 1 | butaritari
# --------------------------------------------------------
# Processing Record 22 of Set 1 | visnes
# --------------------------------------------------------
# Processing Record 23 of Set 1 | chokurdakh
# --------------------------------------------------------
# Processing Record 24 of Set 1 | khani
# --------------------------------------------------------
# Processing Record 25 of Set 1 | vuktyl
# --------------------------------------------------------
# Processing Record 26 of Set 1 | fairbanks
# --------------------------------------------------------
# Processing Record 27 of Set 1 | natal
# --------------------------------------------------------
# Processing Record 28 of Set 1 | arraial do cabo
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 29 of Set 1 | katsuura
# --------------------------------------------------------
# Processing Record 30 of Set 1 | busselton
# --------------------------------------------------------
# Processing Record 31 of Set 1 | avera
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 32 of Set 1 | itoman
# --------------------------------------------------------
# Processing Record 33 of Set 1 | anadyr
# --------------------------------------------------------
# Processing Record 34 of Set 1 | carnarvon
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 35 of Set 1 | katherine
# --------------------------------------------------------
# Processing Record 36 of Set 1 | roanoke rapids
# --------------------------------------------------------
# Processing Record 37 of Set 1 | mehamn
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 38 of Set 1 | kapaa
# --------------------------------------------------------
# Processing Record 39 of Set 1 | nanortalik
# --------------------------------------------------------
# Processing Record 40 of Set 1 | vaini
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 41 of Set 1 | tateyama
# --------------------------------------------------------
# Processing Record 42 of Set 1 | burnie
# --------------------------------------------------------
# Processing Record 43 of Set 1 | avarua
# --------------------------------------------------------
# Processing Record 44 of Set 1 | bredasdorp
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 45 of Set 1 | mandurah
# --------------------------------------------------------
# Processing Record 46 of Set 1 | lotoshino
# --------------------------------------------------------
# Processing Record 47 of Set 1 | bac can
# --------------------------------------------------------
# Processing Record 48 of Set 1 | nantucket
# --------------------------------------------------------
# Processing Record 49 of Set 1 | port elizabeth
# --------------------------------------------------------
# Processing Record 1 of Set 2 | lagoa
# --------------------------------------------------------
# Processing Record 2 of Set 2 | bambous virieux
# --------------------------------------------------------
# Processing Record 3 of Set 2 | xining
# --------------------------------------------------------
# Processing Record 4 of Set 2 | bluff
# --------------------------------------------------------
# Processing Record 5 of Set 2 | new norfolk
# --------------------------------------------------------
# Processing Record 6 of Set 2 | punta arenas
# --------------------------------------------------------
# Processing Record 7 of Set 2 | pankrushikha
# --------------------------------------------------------
# Processing Record 8 of Set 2 | port hedland
# --------------------------------------------------------
# Processing Record 9 of Set 2 | caravelas
# --------------------------------------------------------
# Processing Record 10 of Set 2 | jamestown
# --------------------------------------------------------
# Processing Record 11 of Set 2 | alofi
# --------------------------------------------------------
# Processing Record 12 of Set 2 | jumla
# --------------------------------------------------------
# Processing Record 13 of Set 2 | abu samrah
# --------------------------------------------------------
# Processing Record 14 of Set 2 | georgetown
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 15 of Set 2 | castro
# --------------------------------------------------------
# Processing Record 16 of Set 2 | provideniya
# --------------------------------------------------------
# Processing Record 17 of Set 2 | chuy
# --------------------------------------------------------
# Processing Record 18 of Set 2 | clyde river
# --------------------------------------------------------
# Processing Record 19 of Set 2 | bontang
# --------------------------------------------------------
# Processing Record 20 of Set 2 | hobart
# --------------------------------------------------------
# Processing Record 21 of Set 2 | cape town
# --------------------------------------------------------
# Processing Record 22 of Set 2 | clausthal-zellerfeld
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 23 of Set 2 | bubaque
# --------------------------------------------------------
# Processing Record 24 of Set 2 | yumen
# --------------------------------------------------------
# Processing Record 25 of Set 2 | linqiong
# --------------------------------------------------------
# Processing Record 26 of Set 2 | yellowknife
# --------------------------------------------------------
# Processing Record 27 of Set 2 | luderitz
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 28 of Set 2 | saint-pierre
# --------------------------------------------------------
# Processing Record 29 of Set 2 | palembang
# --------------------------------------------------------
# Processing Record 30 of Set 2 | halifax
# --------------------------------------------------------
# Processing Record 31 of Set 2 | grand river south east
# --------------------------------------------------------
# Processing Record 32 of Set 2 | xuddur
# --------------------------------------------------------
# Processing Record 33 of Set 2 | codrington
# --------------------------------------------------------
# Processing Record 34 of Set 2 | hilo
# --------------------------------------------------------
# Processing Record 35 of Set 2 | khvastovichi
# --------------------------------------------------------
# Processing Record 36 of Set 2 | east london
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 37 of Set 2 | victoria
# --------------------------------------------------------
# Processing Record 38 of Set 2 | severo-kurilsk
# --------------------------------------------------------
# Processing Record 39 of Set 2 | barrow
# --------------------------------------------------------
# Processing Record 40 of Set 2 | cotonou
# --------------------------------------------------------
# Processing Record 41 of Set 2 | kodiak
# --------------------------------------------------------
# Processing Record 42 of Set 2 | saint-joseph
# --------------------------------------------------------
# Processing Record 43 of Set 2 | bathsheba
# --------------------------------------------------------
# Processing Record 44 of Set 2 | zhezkazgan
# --------------------------------------------------------
# Processing Record 45 of Set 2 | sakiai
# --------------------------------------------------------
# Processing Record 46 of Set 2 | ayan
# --------------------------------------------------------
# Processing Record 47 of Set 2 | noshiro
# --------------------------------------------------------
# Processing Record 48 of Set 2 | mvuma
# --------------------------------------------------------
# Processing Record 49 of Set 2 | kihei
# --------------------------------------------------------
# Processing Record 1 of Set 3 | sola
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 2 of Set 3 | pyaozerskiy
# --------------------------------------------------------
# Processing Record 3 of Set 3 | labytnangi
# --------------------------------------------------------
# Processing Record 4 of Set 3 | babu
# --------------------------------------------------------
# Processing Record 5 of Set 3 | nova friburgo
# --------------------------------------------------------
# Processing Record 6 of Set 3 | whitehorse
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 7 of Set 3 | nizhnyaya tavda
# --------------------------------------------------------
# Processing Record 8 of Set 3 | karasburg
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 9 of Set 3 | moroni
# --------------------------------------------------------
# Processing Record 10 of Set 3 | makakilo city
# --------------------------------------------------------
# Processing Record 11 of Set 3 | bandarbeyla
# --------------------------------------------------------
# Processing Record 12 of Set 3 | klyuchi
# --------------------------------------------------------
# Processing Record 13 of Set 3 | guerrero negro
# --------------------------------------------------------
# Processing Record 14 of Set 3 | mahebourg
# --------------------------------------------------------
# Processing Record 15 of Set 3 | tasiilaq
# --------------------------------------------------------
# Processing Record 16 of Set 3 | lavrentiya
# --------------------------------------------------------
# Processing Record 17 of Set 3 | malinyi
# --------------------------------------------------------
# Processing Record 18 of Set 3 | marzuq
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 19 of Set 3 | rorvik
# --------------------------------------------------------
# Processing Record 20 of Set 3 | lompoc
# --------------------------------------------------------
# Processing Record 21 of Set 3 | jalu
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 22 of Set 3 | chingirlau
# --------------------------------------------------------
# Processing Record 23 of Set 3 | richards bay
# --------------------------------------------------------
# Processing Record 24 of Set 3 | plattsburgh
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 25 of Set 3 | taseyevo
# --------------------------------------------------------
# Processing Record 26 of Set 3 | saldanha
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 27 of Set 3 | kushiro
# --------------------------------------------------------
# Processing Record 28 of Set 3 | san rafael
# --------------------------------------------------------
# Processing Record 29 of Set 3 | upernavik
# --------------------------------------------------------
# Processing Record 30 of Set 3 | dikson
# --------------------------------------------------------
# Processing Record 31 of Set 3 | coquimbo
# --------------------------------------------------------
# Processing Record 32 of Set 3 | hanzhong
# --------------------------------------------------------
# Processing Record 33 of Set 3 | cidreira
# --------------------------------------------------------
# Processing Record 34 of Set 3 | uaua
# --------------------------------------------------------
# Processing Record 35 of Set 3 | puerto leguizamo
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 36 of Set 3 | saint-philippe
# --------------------------------------------------------
# Processing Record 37 of Set 3 | kirksville
# --------------------------------------------------------
# Processing Record 38 of Set 3 | beringovskiy
# --------------------------------------------------------
# Processing Record 39 of Set 3 | buriti bravo
# --------------------------------------------------------
# Processing Record 40 of Set 3 | tupik
# --------------------------------------------------------
# Processing Record 41 of Set 3 | kununurra
# --------------------------------------------------------
# Processing Record 42 of Set 3 | yokadouma
# --------------------------------------------------------
# Processing Record 43 of Set 3 | kavieng
# --------------------------------------------------------
# Processing Record 44 of Set 3 | puerto ayora
# --------------------------------------------------------
# Processing Record 45 of Set 3 | san cristobal
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 46 of Set 3 | ostercappeln
# --------------------------------------------------------
# Processing Record 47 of Set 3 | talara
# --------------------------------------------------------
# Processing Record 48 of Set 3 | hendek
# --------------------------------------------------------
# Processing Record 49 of Set 3 | hoi an
# --------------------------------------------------------
# Processing Record 1 of Set 4 | moranbah
# --------------------------------------------------------
# Processing Record 2 of Set 4 | caarapo
# --------------------------------------------------------
# Processing Record 3 of Set 4 | taoudenni
# --------------------------------------------------------
# Processing Record 4 of Set 4 | harper
# --------------------------------------------------------
# Processing Record 5 of Set 4 | ust-maya
# --------------------------------------------------------
# Processing Record 6 of Set 4 | shingu
# --------------------------------------------------------
# Processing Record 7 of Set 4 | grindavik
# --------------------------------------------------------
# Processing Record 8 of Set 4 | ilulissat
# --------------------------------------------------------
# Processing Record 9 of Set 4 | uttaradit
# --------------------------------------------------------
# Processing Record 10 of Set 4 | dingle
# --------------------------------------------------------
# Processing Record 11 of Set 4 | vardo
# --------------------------------------------------------
# Processing Record 12 of Set 4 | pingxiang
# --------------------------------------------------------
# Processing Record 13 of Set 4 | kaitangata
# --------------------------------------------------------
# Processing Record 14 of Set 4 | tinalmud
# --------------------------------------------------------
# Processing Record 15 of Set 4 | lorengau
# --------------------------------------------------------
# Processing Record 16 of Set 4 | nampula
# --------------------------------------------------------
# Processing Record 17 of Set 4 | hatillo
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 18 of Set 4 | berdigestyakh
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 19 of Set 4 | laurel
# --------------------------------------------------------
# Processing Record 20 of Set 4 | nikolskoye
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 21 of Set 4 | portland
# --------------------------------------------------------
# Processing Record 22 of Set 4 | lakes entrance
# --------------------------------------------------------
# Processing Record 23 of Set 4 | arkhangelsk
# --------------------------------------------------------
# Processing Record 24 of Set 4 | tura
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 25 of Set 4 | princeton
# --------------------------------------------------------
# Processing Record 26 of Set 4 | nicolas bravo
# --------------------------------------------------------
# Processing Record 27 of Set 4 | hasaki
# --------------------------------------------------------
# Processing Record 28 of Set 4 | nome
# --------------------------------------------------------
# Processing Record 29 of Set 4 | bonthe
# --------------------------------------------------------
# Processing Record 30 of Set 4 | sinnamary
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 31 of Set 4 | norman wells
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 32 of Set 4 | newry
# --------------------------------------------------------
# Processing Record 33 of Set 4 | ponta do sol
# --------------------------------------------------------
# Processing Record 34 of Set 4 | thompson
# --------------------------------------------------------
# Processing Record 35 of Set 4 | tual
# --------------------------------------------------------
# Processing Record 36 of Set 4 | awjilah
# --------------------------------------------------------
# Processing Record 37 of Set 4 | lebu
# --------------------------------------------------------
# Processing Record 38 of Set 4 | samana
# --------------------------------------------------------
# Processing Record 39 of Set 4 | port lincoln
# --------------------------------------------------------
# Processing Record 40 of Set 4 | mackay
# --------------------------------------------------------
# Processing Record 41 of Set 4 | tabou
# --------------------------------------------------------
# Processing Record 42 of Set 4 | puerto del rosario
# --------------------------------------------------------
# Processing Record 43 of Set 4 | talaya
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 44 of Set 4 | teterow
# --------------------------------------------------------
# Processing Record 45 of Set 4 | napanee
# --------------------------------------------------------
# Processing Record 46 of Set 4 | faanui
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 47 of Set 4 | kimbe
# --------------------------------------------------------
# Processing Record 48 of Set 4 | klaksvik
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 4 | rawson
# --------------------------------------------------------
# Processing Record 1 of Set 5 | ribeira grande
# --------------------------------------------------------
# Processing Record 2 of Set 5 | kargasok
# --------------------------------------------------------
# Processing Record 3 of Set 5 | longyearbyen
# --------------------------------------------------------
# Processing Record 4 of Set 5 | aksu
# --------------------------------------------------------
# Processing Record 5 of Set 5 | bilma
# --------------------------------------------------------
# Processing Record 6 of Set 5 | komsomolskiy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 7 of Set 5 | cherskiy
# --------------------------------------------------------
# Processing Record 8 of Set 5 | ararat
# --------------------------------------------------------
# Processing Record 9 of Set 5 | willmar
# --------------------------------------------------------
# Processing Record 10 of Set 5 | kibala
# --------------------------------------------------------
# Processing Record 11 of Set 5 | kruisfontein
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 12 of Set 5 | amguri
# --------------------------------------------------------
# Processing Record 13 of Set 5 | igrim
# --------------------------------------------------------
# Processing Record 14 of Set 5 | broome
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 15 of Set 5 | roald
# --------------------------------------------------------
# Processing Record 16 of Set 5 | fuldatal
# --------------------------------------------------------
# Processing Record 17 of Set 5 | ostersund
# --------------------------------------------------------
# Processing Record 18 of Set 5 | grand-santi
# --------------------------------------------------------
# Processing Record 19 of Set 5 | gilgit
# --------------------------------------------------------
# Processing Record 20 of Set 5 | okhotsk
# --------------------------------------------------------
# Processing Record 21 of Set 5 | vao
# --------------------------------------------------------
# Processing Record 22 of Set 5 | bonfim
# --------------------------------------------------------
# Processing Record 23 of Set 5 | serov
# --------------------------------------------------------
# Processing Record 24 of Set 5 | killybegs
# --------------------------------------------------------
# Processing Record 25 of Set 5 | dhidhdhoo
# --------------------------------------------------------
# Processing Record 26 of Set 5 | verkhniy mamon
# --------------------------------------------------------
# Processing Record 27 of Set 5 | tiksi
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 28 of Set 5 | pisco
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 29 of Set 5 | vangaindrano
# --------------------------------------------------------
# Processing Record 30 of Set 5 | iquitos
# --------------------------------------------------------
# Processing Record 31 of Set 5 | pathein
# --------------------------------------------------------
# Processing Record 32 of Set 5 | kahului
# --------------------------------------------------------
# Processing Record 33 of Set 5 | nauta
# --------------------------------------------------------
# Processing Record 34 of Set 5 | pangnirtung
# --------------------------------------------------------
# Processing Record 35 of Set 5 | khorixas
# --------------------------------------------------------
# Processing Record 36 of Set 5 | bethel
# --------------------------------------------------------
# Processing Record 37 of Set 5 | vila franca do campo
# --------------------------------------------------------
# Processing Record 38 of Set 5 | groa
# --------------------------------------------------------
# Processing Record 39 of Set 5 | dunedin
# --------------------------------------------------------
# Processing Record 40 of Set 5 | sabha
# --------------------------------------------------------
# Processing Record 41 of Set 5 | khatanga
# --------------------------------------------------------
# Processing Record 42 of Set 5 | goderich
# --------------------------------------------------------
# Processing Record 43 of Set 5 | vila
# --------------------------------------------------------
# Processing Record 44 of Set 5 | ketchikan
# --------------------------------------------------------
# Processing Record 45 of Set 5 | meulaboh
# --------------------------------------------------------
# Processing Record 46 of Set 5 | corigliano calabro
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 47 of Set 5 | namatanai
# --------------------------------------------------------
# Processing Record 48 of Set 5 | fortuna
# --------------------------------------------------------
# Processing Record 49 of Set 5 | beira
# --------------------------------------------------------
# Processing Record 1 of Set 6 | boa vista
# --------------------------------------------------------
# Processing Record 2 of Set 6 | airai
# --------------------------------------------------------
# Processing Record 3 of Set 6 | san pedro de macoris
# --------------------------------------------------------
# Processing Record 4 of Set 6 | pevek
# --------------------------------------------------------
# Processing Record 5 of Set 6 | gayny
# --------------------------------------------------------
# Processing Record 6 of Set 6 | port hardy
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 7 of Set 6 | castres
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 8 of Set 6 | riberalta
# --------------------------------------------------------
# Processing Record 9 of Set 6 | terrace bay
# --------------------------------------------------------
# Processing Record 10 of Set 6 | mecca
# --------------------------------------------------------
# Processing Record 11 of Set 6 | torbay
# --------------------------------------------------------
# Processing Record 12 of Set 6 | solnechnyy
# --------------------------------------------------------
# Processing Record 13 of Set 6 | sambava
# --------------------------------------------------------
# Processing Record 14 of Set 6 | bani
# --------------------------------------------------------
# Processing Record 15 of Set 6 | esperance
# --------------------------------------------------------
# Processing Record 16 of Set 6 | husavik
# --------------------------------------------------------
# Processing Record 17 of Set 6 | quelimane
# --------------------------------------------------------
# Processing Record 18 of Set 6 | bouloupari
# --------------------------------------------------------
# Processing Record 19 of Set 6 | san quintin
# --------------------------------------------------------
# Processing Record 20 of Set 6 | santa isabel
# --------------------------------------------------------
# Processing Record 21 of Set 6 | brigantine
# --------------------------------------------------------
# Processing Record 22 of Set 6 | mar del plata
# --------------------------------------------------------
# Processing Record 23 of Set 6 | omboue
# --------------------------------------------------------
# Processing Record 24 of Set 6 | bollnas
# --------------------------------------------------------
# Processing Record 25 of Set 6 | iqaluit
# --------------------------------------------------------
# Processing Record 26 of Set 6 | huarmey
# --------------------------------------------------------
# Processing Record 27 of Set 6 | moyale
# --------------------------------------------------------
# Processing Record 28 of Set 6 | wamba
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 29 of Set 6 | coihaique
# --------------------------------------------------------
# Processing Record 30 of Set 6 | alta floresta
# --------------------------------------------------------
# Processing Record 31 of Set 6 | sabang
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 32 of Set 6 | san ignacio
# --------------------------------------------------------
# Processing Record 33 of Set 6 | kulunda
# --------------------------------------------------------
# Processing Record 34 of Set 6 | puerto colombia
# --------------------------------------------------------
# Processing Record 35 of Set 6 | san jeronimo
# --------------------------------------------------------
# Processing Record 36 of Set 6 | wanning
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 37 of Set 6 | huntington
# --------------------------------------------------------
# Processing Record 38 of Set 6 | talnakh
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 39 of Set 6 | ornskoldsvik
# --------------------------------------------------------
# Processing Record 40 of Set 6 | idrinskoye
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 41 of Set 6 | ohara
# --------------------------------------------------------
# Processing Record 42 of Set 6 | san vicente
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 43 of Set 6 | sur
# --------------------------------------------------------
# Processing Record 44 of Set 6 | svetlaya
# --------------------------------------------------------
# Processing Record 45 of Set 6 | bealanana
# --------------------------------------------------------
# Processing Record 46 of Set 6 | ust-tsilma
# --------------------------------------------------------
# Processing Record 47 of Set 6 | barra patuca
# --------------------------------------------------------
# Processing Record 48 of Set 6 | makueni
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 6 | patti
# --------------------------------------------------------
# Processing Record 1 of Set 7 | oriximina
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 2 of Set 7 | ahuimanu
# --------------------------------------------------------
# Processing Record 3 of Set 7 | bur gabo
# --------------------------------------------------------
# Processing Record 4 of Set 7 | kasongo-lunda
# --------------------------------------------------------
# Processing Record 5 of Set 7 | nouadhibou
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 6 of Set 7 | kenitra
# --------------------------------------------------------
# Processing Record 7 of Set 7 | axim
# --------------------------------------------------------
# Processing Record 8 of Set 7 | oyama
# --------------------------------------------------------
# Processing Record 9 of Set 7 | burlington
# --------------------------------------------------------
# Processing Record 10 of Set 7 | monrovia
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 11 of Set 7 | malpe
# --------------------------------------------------------
# Processing Record 12 of Set 7 | nadym
# --------------------------------------------------------
# Processing Record 13 of Set 7 | beeville
# --------------------------------------------------------
# Processing Record 14 of Set 7 | bonoua
# --------------------------------------------------------
# Processing Record 15 of Set 7 | trairi
# --------------------------------------------------------
# Processing Record 16 of Set 7 | evensk
# --------------------------------------------------------
# Processing Record 17 of Set 7 | yar-sale
# --------------------------------------------------------
# Processing Record 18 of Set 7 | muros
# --------------------------------------------------------
# Processing Record 19 of Set 7 | deputatskiy
# --------------------------------------------------------
# Processing Record 20 of Set 7 | cabo san lucas
# --------------------------------------------------------
# Processing Record 21 of Set 7 | reconquista
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 22 of Set 7 | laramie
# --------------------------------------------------------
# Processing Record 23 of Set 7 | miri
# --------------------------------------------------------
# Processing Record 24 of Set 7 | srednekolymsk
# --------------------------------------------------------
# Processing Record 25 of Set 7 | manaquiri
# --------------------------------------------------------
# Processing Record 26 of Set 7 | padang
# --------------------------------------------------------
# Processing Record 27 of Set 7 | aquiraz
# --------------------------------------------------------
# Processing Record 28 of Set 7 | trinidad
# --------------------------------------------------------
# Processing Record 29 of Set 7 | egvekinot
# --------------------------------------------------------
# Processing Record 30 of Set 7 | beysehir
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 31 of Set 7 | sitka
# --------------------------------------------------------
# Processing Record 32 of Set 7 | wattegama
# --------------------------------------------------------
# Processing Record 33 of Set 7 | trelew
# --------------------------------------------------------
# Processing Record 34 of Set 7 | matara
# --------------------------------------------------------
# Processing Record 35 of Set 7 | guane
# --------------------------------------------------------
# Processing Record 36 of Set 7 | chinsali
# --------------------------------------------------------
# Processing Record 37 of Set 7 | vila velha
# --------------------------------------------------------
# Processing Record 38 of Set 7 | yining
# --------------------------------------------------------
# Processing Record 39 of Set 7 | gorontalo
# --------------------------------------------------------
# Processing Record 40 of Set 7 | isangel
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 41 of Set 7 | hanmer springs
# --------------------------------------------------------
# Processing Record 42 of Set 7 | port-gentil
# --------------------------------------------------------
# Processing Record 43 of Set 7 | gornopravdinsk
# --------------------------------------------------------
# Processing Record 44 of Set 7 | ucluelet
# --------------------------------------------------------
# Processing Record 45 of Set 7 | vestmanna
# --------------------------------------------------------
# Processing Record 46 of Set 7 | martan-chu
# --------------------------------------------------------
# Processing Record 47 of Set 7 | laguna
# --------------------------------------------------------
# Processing Record 48 of Set 7 | sao filipe
# --------------------------------------------------------
# Processing Record 49 of Set 7 | ostrovnoy
# --------------------------------------------------------
# Processing Record 1 of Set 8 | coahuayana
# --------------------------------------------------------
# Processing Record 2 of Set 8 | brewster
# --------------------------------------------------------
# Processing Record 3 of Set 8 | caohai
# --------------------------------------------------------
# Processing Record 4 of Set 8 | oran
# --------------------------------------------------------
# Processing Record 5 of Set 8 | gigmoto
# --------------------------------------------------------
# Processing Record 6 of Set 8 | bousse
# --------------------------------------------------------
# Processing Record 7 of Set 8 | praia da vitoria
# --------------------------------------------------------
# Processing Record 8 of Set 8 | nabire
# --------------------------------------------------------
# Processing Record 9 of Set 8 | shakiso
# --------------------------------------------------------
# Processing Record 10 of Set 8 | gushikawa
# --------------------------------------------------------
# Processing Record 11 of Set 8 | solvychegodsk
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 12 of Set 8 | phan thiet
# --------------------------------------------------------
# Processing Record 13 of Set 8 | chimbote
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 14 of Set 8 | skvyra
# --------------------------------------------------------
# Processing Record 15 of Set 8 | litovko
# --------------------------------------------------------
# Processing Record 16 of Set 8 | trincomalee
# --------------------------------------------------------
# Processing Record 17 of Set 8 | turukhansk
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 18 of Set 8 | mokolo
# --------------------------------------------------------
# Processing Record 19 of Set 8 | simpang
# --------------------------------------------------------
# Processing Record 20 of Set 8 | shinuhayr
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 21 of Set 8 | hay river
# --------------------------------------------------------
# Processing Record 22 of Set 8 | souillac
# --------------------------------------------------------
# Processing Record 23 of Set 8 | half moon bay
# --------------------------------------------------------
# Processing Record 24 of Set 8 | sept-iles
# --------------------------------------------------------
# Processing Record 25 of Set 8 | gweta
# --------------------------------------------------------
# Processing Record 26 of Set 8 | at-bashi
# --------------------------------------------------------
# Processing Record 27 of Set 8 | ocampo
# --------------------------------------------------------
# Processing Record 28 of Set 8 | nizhniy kuranakh
# --------------------------------------------------------
# Processing Record 29 of Set 8 | pimentel
# --------------------------------------------------------
# Processing Record 30 of Set 8 | san patricio
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 31 of Set 8 | auckland
# --------------------------------------------------------
# Processing Record 32 of Set 8 | freetown
# --------------------------------------------------------
# Processing Record 33 of Set 8 | svobodnyy
# --------------------------------------------------------
# Processing Record 34 of Set 8 | dryden
# --------------------------------------------------------
# Processing Record 35 of Set 8 | churapcha
# --------------------------------------------------------
# Processing Record 36 of Set 8 | tuatapere
# --------------------------------------------------------
# Processing Record 37 of Set 8 | oksfjord
# --------------------------------------------------------
# Processing Record 38 of Set 8 | vanimo
# --------------------------------------------------------
# Processing Record 39 of Set 8 | ghanzi
# --------------------------------------------------------
# Processing Record 40 of Set 8 | puerto escondido
# --------------------------------------------------------
# Processing Record 41 of Set 8 | andros
# --------------------------------------------------------
# Processing Record 42 of Set 8 | gazanjyk
# --------------------------------------------------------
# Processing Record 43 of Set 8 | hlobyne
# --------------------------------------------------------
# Processing Record 44 of Set 8 | heihe
# --------------------------------------------------------
# Processing Record 45 of Set 8 | hualmay
# --------------------------------------------------------
# Processing Record 46 of Set 8 | port hawkesbury
# --------------------------------------------------------
# Processing Record 47 of Set 8 | high level
# --------------------------------------------------------
# Processing Record 48 of Set 8 | ewa beach
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 8 | pilar de la horadada
# --------------------------------------------------------
# Processing Record 1 of Set 9 | kalmunai
# --------------------------------------------------------
# Processing Record 2 of Set 9 | poopo
# --------------------------------------------------------
# Processing Record 3 of Set 9 | winslow
# --------------------------------------------------------
# Processing Record 4 of Set 9 | juigalpa
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 5 of Set 9 | usinsk
# --------------------------------------------------------
# Processing Record 6 of Set 9 | ntungamo
# --------------------------------------------------------
# Processing Record 7 of Set 9 | antalaha
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 8 of Set 9 | sorong
# --------------------------------------------------------
# Processing Record 9 of Set 9 | alice springs
# --------------------------------------------------------
# Processing Record 10 of Set 9 | bibiani
# --------------------------------------------------------
# Processing Record 11 of Set 9 | taraz
# --------------------------------------------------------
# Processing Record 12 of Set 9 | alghero
# --------------------------------------------------------
# Processing Record 13 of Set 9 | mount gambier
# --------------------------------------------------------
# Processing Record 14 of Set 9 | cooma
# --------------------------------------------------------
# Processing Record 15 of Set 9 | victor harbor
# --------------------------------------------------------
# Processing Record 16 of Set 9 | bodrum
# --------------------------------------------------------
# Processing Record 17 of Set 9 | fukue
# --------------------------------------------------------
# Processing Record 18 of Set 9 | sao gabriel da cachoeira
# --------------------------------------------------------
# Processing Record 19 of Set 9 | totness
# --------------------------------------------------------
# Processing Record 20 of Set 9 | mishan
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 21 of Set 9 | hope
# --------------------------------------------------------
# Processing Record 22 of Set 9 | mutis
# --------------------------------------------------------
# Processing Record 23 of Set 9 | merritt island
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 24 of Set 9 | ukiah
# --------------------------------------------------------
# Processing Record 25 of Set 9 | galle
# --------------------------------------------------------
# Processing Record 26 of Set 9 | powell river
# --------------------------------------------------------
# Processing Record 27 of Set 9 | bereza
# --------------------------------------------------------
# Processing Record 28 of Set 9 | salalah
# --------------------------------------------------------
# Processing Record 29 of Set 9 | ahvaz
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 30 of Set 9 | imbituba
# --------------------------------------------------------
# Processing Record 31 of Set 9 | kiama
# --------------------------------------------------------
# Processing Record 32 of Set 9 | cholet
# --------------------------------------------------------
# Processing Record 33 of Set 9 | inirida
# --------------------------------------------------------
# Processing Record 34 of Set 9 | qui nhon
# --------------------------------------------------------
# Processing Record 35 of Set 9 | tahoua
# --------------------------------------------------------
# Processing Record 36 of Set 9 | hirara
# --------------------------------------------------------
# Processing Record 37 of Set 9 | sorland
# --------------------------------------------------------
# Processing Record 38 of Set 9 | erzin
# --------------------------------------------------------
# Processing Record 39 of Set 9 | sisimiut
# --------------------------------------------------------
# Processing Record 40 of Set 9 | kaka
# --------------------------------------------------------
# Processing Record 41 of Set 9 | buraydah
# --------------------------------------------------------
# Processing Record 42 of Set 9 | zhigansk
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 43 of Set 9 | osakarovka
# --------------------------------------------------------
# Processing Record 44 of Set 9 | beloha
# --------------------------------------------------------
# Processing Record 45 of Set 9 | businga
# --------------------------------------------------------
# Processing Record 46 of Set 9 | faya
# --------------------------------------------------------
# Processing Record 47 of Set 9 | tiarei
# --------------------------------------------------------
# Processing Record 48 of Set 9 | lubao
# --------------------------------------------------------
# Processing Record 49 of Set 9 | zaragoza
# --------------------------------------------------------
# Processing Record 1 of Set 10 | itarantim
# --------------------------------------------------------
# City not found.... Searching...
# City not found.... Searching...
# Processing Record 2 of Set 10 | talcahuano
# --------------------------------------------------------
# Processing Record 3 of Set 10 | muret
# --------------------------------------------------------
# Processing Record 4 of Set 10 | shimoda
# --------------------------------------------------------
# Processing Record 5 of Set 10 | kamenka
# --------------------------------------------------------
# Processing Record 6 of Set 10 | fort nelson
# --------------------------------------------------------
# Processing Record 7 of Set 10 | havre-saint-pierre
# --------------------------------------------------------
# Processing Record 8 of Set 10 | haines junction
# --------------------------------------------------------
# Processing Record 9 of Set 10 | tingi
# --------------------------------------------------------
# Processing Record 10 of Set 10 | torri di quartesolo
# --------------------------------------------------------
# Processing Record 11 of Set 10 | kangaatsiaq
# --------------------------------------------------------
# Processing Record 12 of Set 10 | aswan
# --------------------------------------------------------
# Processing Record 13 of Set 10 | ahipara
# --------------------------------------------------------
# Processing Record 14 of Set 10 | northam
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 15 of Set 10 | savinka
# --------------------------------------------------------
# Processing Record 16 of Set 10 | otradnoye
# --------------------------------------------------------
# Processing Record 17 of Set 10 | lubango
# --------------------------------------------------------
# Processing Record 18 of Set 10 | mountain home
# --------------------------------------------------------
# Processing Record 19 of Set 10 | cap-chat
# --------------------------------------------------------
# Processing Record 20 of Set 10 | neryungri
# --------------------------------------------------------
# Processing Record 21 of Set 10 | batticaloa
# --------------------------------------------------------
# Processing Record 22 of Set 10 | lapeer
# --------------------------------------------------------
# Processing Record 23 of Set 10 | honningsvag
# --------------------------------------------------------
# Processing Record 24 of Set 10 | shieli
# --------------------------------------------------------
# Processing Record 25 of Set 10 | teahupoo
# --------------------------------------------------------
# Processing Record 26 of Set 10 | pacific grove
# --------------------------------------------------------
# Processing Record 27 of Set 10 | labuhan
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 28 of Set 10 | nemuro
# --------------------------------------------------------
# Processing Record 29 of Set 10 | valkeakoski
# --------------------------------------------------------
# Processing Record 30 of Set 10 | kyshtovka
# --------------------------------------------------------
# Processing Record 31 of Set 10 | santa eulalia
# --------------------------------------------------------
# Processing Record 32 of Set 10 | lata
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 33 of Set 10 | champerico
# --------------------------------------------------------
# Processing Record 34 of Set 10 | leningradskiy
# --------------------------------------------------------
# Processing Record 35 of Set 10 | pandharpur
# --------------------------------------------------------
# Processing Record 36 of Set 10 | kintampo
# --------------------------------------------------------
# Processing Record 37 of Set 10 | kabo
# --------------------------------------------------------
# Processing Record 38 of Set 10 | pankovka
# --------------------------------------------------------
# Processing Record 39 of Set 10 | buin
# --------------------------------------------------------
# Processing Record 40 of Set 10 | khanpur
# --------------------------------------------------------
# Processing Record 41 of Set 10 | tarakan
# --------------------------------------------------------
# Processing Record 42 of Set 10 | gat
# --------------------------------------------------------
# Processing Record 43 of Set 10 | itai
# --------------------------------------------------------
# Processing Record 44 of Set 10 | jiazi
# --------------------------------------------------------
# Processing Record 45 of Set 10 | itapeva
# --------------------------------------------------------
# Processing Record 46 of Set 10 | hoquiam
# --------------------------------------------------------
# Processing Record 47 of Set 10 | ofunato
# --------------------------------------------------------
# Processing Record 48 of Set 10 | vostok
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 49 of Set 10 | russell
# --------------------------------------------------------
# Processing Record 1 of Set 11 | karlshamn
# --------------------------------------------------------
# Processing Record 2 of Set 11 | inhambane
# --------------------------------------------------------
# Processing Record 3 of Set 11 | gillette
# --------------------------------------------------------
# Processing Record 4 of Set 11 | adrar
# --------------------------------------------------------
# Processing Record 5 of Set 11 | college
# --------------------------------------------------------
# Processing Record 6 of Set 11 | taft
# --------------------------------------------------------
# Processing Record 7 of Set 11 | beyneu
# --------------------------------------------------------
# Processing Record 8 of Set 11 | tam ky
# --------------------------------------------------------
# Processing Record 9 of Set 11 | palanga
# --------------------------------------------------------
# Processing Record 10 of Set 11 | praia
# --------------------------------------------------------
# Processing Record 11 of Set 11 | lhokseumawe
# --------------------------------------------------------
# Processing Record 12 of Set 11 | bintulu
# --------------------------------------------------------
# Processing Record 13 of Set 11 | troitsko-pechorsk
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 14 of Set 11 | alyangula
# --------------------------------------------------------
# Processing Record 15 of Set 11 | moose factory
# --------------------------------------------------------
# Processing Record 16 of Set 11 | dzerzhinsk
# --------------------------------------------------------
# Processing Record 17 of Set 11 | marienburg
# --------------------------------------------------------
# Processing Record 18 of Set 11 | ler
# --------------------------------------------------------
# Processing Record 19 of Set 11 | sann
# --------------------------------------------------------
# Processing Record 20 of Set 11 | angoche
# --------------------------------------------------------
# Processing Record 21 of Set 11 | alikalia
# --------------------------------------------------------
# Processing Record 22 of Set 11 | corn island
# --------------------------------------------------------
# Processing Record 23 of Set 11 | arlit
# --------------------------------------------------------
# Processing Record 24 of Set 11 | paris
# --------------------------------------------------------
# Processing Record 25 of Set 11 | cimahi
# --------------------------------------------------------
# Processing Record 26 of Set 11 | coihueco
# --------------------------------------------------------
# Processing Record 27 of Set 11 | brae
# --------------------------------------------------------
# Processing Record 28 of Set 11 | colac
# --------------------------------------------------------
# City not found.... Searching...
# Processing Record 29 of Set 11 | sheopur
# --------------------------------------------------------
# Processing Record 30 of Set 11 | oranjemund
# --------------------------------------------------------
# Processing Record 31 of Set 11 | ballina
# --------------------------------------------------------
# Processing Record 32 of Set 11 | maralal
# --------------------------------------------------------
# Processing Record 33 of Set 11 | mingshui
# --------------------------------------------------------
# Processing Record 34 of Set 11 | viedma
# --------------------------------------------------------
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_list,
    "Country":countries,
    "Cloudiness":cloudinesses,
    "Humidity":humidities,
    "Latitude":lats,
    "Longitude":lngs,
    "Max Temperature":max_temps,
    "Wind Speed":wind_speeds
}

# %%
# establish dataframe
weather_df = pd.DataFrame(weather_dict)

# %%
# show the top of the dataframe
weather_df.head()
# Out:
#           City Country  Cloudiness  Humidity  Latitude  Longitude  \
# 0      qaanaaq      GL         100        93     77.48     -69.36
# 1      rikitea      PF          88        64    -23.12    -134.97
# 2      corinto      CO          75        69      3.17     -76.26
# 3       atuona      PF          45        69     -9.80    -139.03
# 4  port alfred      CD         100        63     -7.04      29.76
#
#    Max Temperature  Wind Speed
# 0            23.09       13.75
# 1            69.73        8.42
# 2            77.00       11.41
# 3            79.03        4.30
# 4            79.90        5.68

# %%
# output data to csv
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Generate the Plot lat vs. Temp

plt.scatter(weather_df["Latitude"],weather_df["Max Temperature"] )


plt.ylim(-5,120)

# Chart title
plt.title("City Latitude VS Max Temperature")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Max Temperature (°F)")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Generate the Plot lat vs. Humidity

plt.scatter(weather_df["Latitude"],weather_df["Humidity"] )


plt.ylim(-5,115)

# Chart title
plt.title("City Latitude VS Humidity")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Humidity")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSHum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Generate the Plot lat vs. Cloudiness

plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"] )


plt.ylim(-15,125)

# Chart title
plt.title("City Latitude VS Cloudiness")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Cloudiness")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSCloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Generate the Plot lat vs. Wind Speed

plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"] )


# Chart title
plt.title("City Latitude VS Wind Speed")
# x label
plt.xlabel("Latitude")
# y label
plt.ylabel("Wind Speed (meter/sec)")
# legend 

plt.grid(alpha=0.5)

# Show the Figure
plt.show()


# Save the Figure
plt.savefig("./LatVSWind.png")
